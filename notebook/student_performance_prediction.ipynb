# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Student_Performance_Prediction.csv')

df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Extracurricular_Activities  \
# 0             23          84                  Low                         No
# 1             19          64                  Low                         No
# 2             24          98               Medium                        Yes
# 3             29          89                  Low                        Yes
# 4             19          92               Medium                        Yes
#
#    Sleep_Hours  Previous_Scores Motivation_Level Internet_Access  \
# 0            7               73              Low             Yes
# 1            8               59              Low             Yes
# 2            7               91           Medium             Yes
# 3            8               98           Medium             Yes
# 4            6               65           Medium             Yes
#
#    Tutoring_Sessions Family_Income Teacher_Quality School_Type  \
# 0                  0           Low          Medium      Public
# 1                  2        Medium          Medium      Public
# 2                  2        Medium          Medium      Public
# 3                  1        Medium          Medium      Public
# 4                  3        Medium            High      Public
#
#    Physical_Activity Learning_Disabilities Parental_Education_Level  \
# 0                  3                    No              High School
# 1                  4                    No                  College
# 2                  4                    No             Postgraduate
# 3                  4                    No              High School
# 4                  4                    No                  College
#
#   Distance_from_Home  Gender  Exam_Score
# 0               Near    Male          67
# 1           Moderate  Female          61
# 2               Near    Male          74
# 3           Moderate    Male          71
# 4               Near  Female          70

# %%
df.shape
# Out:
# (6607, 18)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Extracurricular_Activities', 'Sleep_Hours', 'Previous_Scores',
#        'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Physical_Activity',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender', 'Exam_Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Extracurricular_Activities  6607 non-null   object
#  4   Sleep_Hours                 6607 non-null   int64
#  5   Previous_Scores             6607 non-null   int64
#  6   Motivation_Level            6607 non-null   object
#  7   Internet_Access             6607 non-null   object
#  8   Tutoring_Sessions           6607 non-null   int64
#  9   Family_Income               6607 non-null   object
#  10  Teacher_Quality             6529 non-null   object
#  11  School_Type                 6607 non-null   object
#  12  Physical_Activity           6607 non-null   int64
#  13  Learning_Disabilities       6607 non-null   object
#  14  Parental_Education_Level    6517 non-null   object
#  15  Distance_from_Home          6540 non-null   object
#  16  Gender                      6607 non-null   object
#  17  Exam_Score                  6607 non-null   int64
# dtypes: int64(7), object(11)
# memory usage: 929.2+ KB

# %%
df.describe(include='all')
# Out:
#         Hours_Studied   Attendance Parental_Involvement  \
# count     6607.000000  6607.000000                 6607
# unique            NaN          NaN                    3
# top               NaN          NaN               Medium
# freq              NaN          NaN                 3362
# mean        19.975329    79.977448                  NaN
# std          5.990594    11.547475                  NaN
# min          1.000000    60.000000                  NaN
# 25%         16.000000    70.000000                  NaN
# 50%         20.000000    80.000000                  NaN
# 75%         24.000000    90.000000                  NaN
# max         44.000000   100.000000                  NaN
#
#        Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# count                        6607   6607.00000      6607.000000
# unique                          2          NaN              NaN
# top                           Yes          NaN              NaN
# freq                         3938          NaN              NaN
# mean                          NaN      7.02906        75.070531
# std                           NaN      1.46812        14.399784
# min                           NaN      4.00000        50.000000
# 25%                           NaN      6.00000        63.000000
# 50%                           NaN      7.00000        75.000000
# 75%                           NaN      8.00000        88.000000
# max                           NaN     10.00000       100.000000
#
#        Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# count              6607            6607        6607.000000          6607
# unique                3               2                NaN             3
# top              Medium             Yes                NaN           Low
# freq               3351            6108                NaN          2672
# mean                NaN             NaN           1.493719           NaN
# std                 NaN             NaN           1.230570           NaN
# min                 NaN             NaN           0.000000           NaN
# 25%                 NaN             NaN           1.000000           NaN
# 50%                 NaN             NaN           1.000000           NaN
# 75%                 NaN             NaN           2.000000           NaN
# max                 NaN             NaN           8.000000           NaN
#
#        Teacher_Quality School_Type  Physical_Activity Learning_Disabilities  \
# count             6529        6607        6607.000000                  6607
# unique               3           2                NaN                     2
# top             Medium      Public                NaN                    No
# freq              3925        4598                NaN                  5912
# mean               NaN         NaN           2.967610                   NaN
# std                NaN         NaN           1.031231                   NaN
# min                NaN         NaN           0.000000                   NaN
# 25%                NaN         NaN           2.000000                   NaN
# 50%                NaN         NaN           3.000000                   NaN
# 75%                NaN         NaN           4.000000                   NaN
# max                NaN         NaN           6.000000                   NaN
#
#        Parental_Education_Level Distance_from_Home Gender   Exam_Score
# count                      6517               6540   6607  6607.000000
# unique                        3                  3      2          NaN
# top                 High School               Near   Male          NaN
# freq                       3223               3884   3814          NaN
# mean                        NaN                NaN    NaN    67.235659
# std                         NaN                NaN    NaN     3.890456
# min                         NaN                NaN    NaN    55.000000
# 25%                         NaN                NaN    NaN    65.000000
# 50%                         NaN                NaN    NaN    67.000000
# 75%                         NaN                NaN    NaN    69.000000
# max                         NaN                NaN    NaN   101.000000

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df['Teacher_Quality'] = df['Teacher_Quality'].fillna(df['Teacher_Quality'].mode()[0])
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(df['Parental_Education_Level'].mode()[0])
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(df['Distance_from_Home'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for column in df.columns:
    print(f"\n{column}")
    print(df[column].unique())
# Out:
# Hours_Studied
# [23 19 24 29 25 17 21  9 10 14 22 15 12 20 11 13 16 18 31  8 26 28  4 35
#  27 33 36 43 34  1 30  7 32  6 38  5  3  2 39 37 44]
#
# Attendance
# [ 84  64  98  89  92  88  78  94  80  97  83  82  68  60  70  75  99  74
#   65  62  91  90  66  69  72  63  61  86  77  71  67  87  73  96 100  81
#   95  79  85  76  93]
#
# Parental_Involvement
# ['Low' 'Medium' 'High']
#
# Extracurricular_Activities
# ['No' 'Yes']
#
# Sleep_Hours
# [ 7  8  6 10  9  5  4]
#
# Previous_Scores
# [ 73  59  91  98  65  89  68  50  80  71  88  87  97  72  74  70  82  58
#   99  84 100  75  54  90  94  51  57  66  96  93  56  52  63  79  81  69
#   95  60  92  77  62  85  78  64  76  55  86  61  53  83  67]
#
# Motivation_Level
# ['Low' 'Medium' 'High']
#
# Internet_Access
# ['Yes' 'No']
#
# Tutoring_Sessions
# [0 2 1 3 4 5 6 7 8]
#
# Family_Income
# ['Low' 'Medium' 'High']
#
# Teacher_Quality
# ['Medium' 'High' 'Low']
#
# School_Type
# ['Public' 'Private']
#
# Physical_Activity
# [3 4 2 1 5 0 6]
#
# Learning_Disabilities
# ['No' 'Yes']
#
# Parental_Education_Level
# ['High School' 'College' 'Postgraduate']
#
# Distance_from_Home
# ['Near' 'Moderate' 'Far']
#
# Gender
# ['Male' 'Female']
#
# Exam_Score
# [ 67  61  74  71  70  66  69  72  68  65  64  60  63  62 100  76  79  73
#   78  89  75  59  86  97  83  84  80  58  94  55  92  82  77 101  88  91
#   99  87  57  96  98  95  85  93  56]

# %%
df.nunique()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement           3
# Extracurricular_Activities     2
# Sleep_Hours                    7
# Previous_Scores               51
# Motivation_Level               3
# Internet_Access                2
# Tutoring_Sessions              9
# Family_Income                  3
# Teacher_Quality                3
# School_Type                    2
# Physical_Activity              7
# Learning_Disabilities          2
# Parental_Education_Level       3
# Distance_from_Home             3
# Gender                         2
# Exam_Score                    45
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Exam_Score'], bins=20, kde=True)
plt.ylabel("Frequency")
plt.title("Distribution of Exam Scores")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Exam_Score'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Hours_Studied', y='Exam_Score', data=df)
plt.title("Hours Studied vs Exam Score")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Attendance', y='Exam_Score', data=df)
plt.title("Attendance vs Exam Score")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Previous_Scores', y='Exam_Score', data=df)
plt.title("Previous Scores vs Exam Score")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Teacher_Quality', data=df)
plt.title("Teacher Quality Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Parental_Education_Level', data=df)
plt.title("Parental Education Level")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='School_Type', data=df)
plt.title("School Type Distribution")
plt.show()

# %%
sns.pairplot(df[['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
X= df.drop('Exam_Score', axis=1)
y=df['Exam_Score']
print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (6607, 17)
# Target Shape: (6607,)

# %%
le = LabelEncoder()

encoders = {}
for column in X.select_dtypes(include='object').columns:
    le = LabelEncoder()
    X[column] = le.fit_transform(X[column])
    encoders[column] = le
X.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  \
# 0             23          84                     1
# 1             19          64                     1
# 2             24          98                     2
# 3             29          89                     1
# 4             19          92                     2
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 1
# 1                           0            8               59                 1
# 2                           1            7               91                 2
# 3                           1            8               98                 2
# 4                           1            6               65                 2
#
#    Internet_Access  Tutoring_Sessions  Family_Income  Teacher_Quality  \
# 0                1                  0              1                2
# 1                1                  2              2                2
# 2                1                  2              2                2
# 3                1                  1              2                2
# 4                1                  3              2                0
#
#    School_Type  Physical_Activity  Learning_Disabilities  \
# 0            1                  3                      0
# 1            1                  4                      0
# 2            1                  4                      0
# 3            1                  4                      0
# 4            1                  4                      0
#
#    Parental_Education_Level  Distance_from_Home  Gender
# 0                         1                   2       1
# 1                         0                   1       0
# 2                         2                   2       1
# 3                         1                   1       1
# 4                         0                   2       0

# %%
X.dtypes
# Out:
# Hours_Studied                 int64
# Attendance                    int64
# Parental_Involvement          int64
# Extracurricular_Activities    int64
# Sleep_Hours                   int64
# Previous_Scores               int64
# Motivation_Level              int64
# Internet_Access               int64
# Tutoring_Sessions             int64
# Family_Income                 int64
# Teacher_Quality               int64
# School_Type                   int64
# Physical_Activity             int64
# Learning_Disabilities         int64
# Parental_Education_Level      int64
# Distance_from_Home            int64
# Gender                        int64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42)
print("Training features:", X_train.shape)
print("Testing Features:", X_test.shape)
print("Training, Target:", y_train.shape)
print("Testing Target:", y_test.shape)
# Out:
# Training features: (5285, 17)
# Testing Features: (1322, 17)
# Training, Target: (5285,)
# Testing Target: (1322,)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
print(X_train_scaled[:5])
# Out:
# [[ 1.1735788  -0.07584643 -0.25498031  0.81907391  0.66909444 -0.83727669
#   -1.68283156  0.29077054  0.40578449 -0.28517617  0.76920413  0.65952368
#    1.96490902 -0.35144261 -1.28776381 -0.73309848 -1.16999695]
#  [-0.66198319  0.53189424 -1.41070152  0.81907391 -0.01674034  1.31472787
#    0.88243086  0.29077054  0.40578449 -0.28517617 -1.45771662  0.65952368
#    0.03038142 -0.35144261  0.14625046 -0.73309848 -1.16999695]
#  [ 0.33923244  0.61871433 -0.25498031 -1.22089104  0.66909444  0.55111335
#   -0.40020035  0.29077054 -0.40501741 -0.28517617  0.76920413  0.65952368
#   -1.90414618 -0.35144261 -1.28776381 -2.21983119  0.85470308]
#  [-0.32824464  1.74737557 -1.41070152  0.81907391  2.040764    0.75937185
#    0.88243086  0.29077054 -0.40501741  1.06411305  0.76920413  0.65952368
#    0.03038142 -0.35144261  0.14625046  0.75363424  0.85470308]
#  [ 2.50853297 -0.16266652 -1.41070152  0.81907391  2.040764    1.66182538
#    0.88243086  0.29077054 -0.40501741 -0.28517617  0.76920413 -1.51624577
#   -0.93688238 -0.35144261  0.14625046  0.75363424  0.85470308]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
lr_model = LinearRegression()
lr_model.fit(X_train_scaled, y_train)
lr_pred = lr_model.predict(X_test_scaled)
print("Linear Regression Prediction:", lr_pred[:5])
# Out:
# Linear Regression Prediction: [65.70763644 67.49310556 69.75605715 66.75518925 66.36078092]

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)
print("Decision Tree Regression Prediction:", dt_pred[:5])
# Out:
# Decision Tree Regression Prediction: [65. 68. 69. 67. 67.]

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
print("Random Forest Regression Prediction:", rf_pred[:5])
# Out:
# Random Forest Regression Prediction: [66.11 67.25 72.47 66.19 65.51]

# %%
xgb_model = XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

xgb_model.fit(X_train, y_train)

xgb_pred = xgb_model.predict(X_test)
print("XGBoost Regression Prediction:", xgb_pred[:5])
# Out:
# XGBoost Regression Prediction: [66.67928  66.34917  71.749756 64.84061  65.74955 ]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
lr_mae = mean_absolute_error(y_test, lr_pred)
lr_mse = mean_squared_error(y_test, lr_pred)
lr_rmse = np.sqrt(lr_mse)
lr_r2 = r2_score(y_test, lr_pred)

print("Linear Regression")
print("MAE :", lr_mae)
print("MSE :", lr_mse)
print("RMSE:", lr_rmse)
print("R² Score:", lr_r2)
# Out:
# Linear Regression
# MAE : 1.1270363912833579
# MSE : 4.676522744963175
# RMSE: 2.162526935083856
# R² Score: 0.6691546680162024

# %%
dt_mae = mean_absolute_error(y_test, dt_pred)
dt_mse = mean_squared_error(y_test, dt_pred)
dt_rmse = np.sqrt(dt_mse)
dt_r2 = r2_score(y_test, dt_pred)

print("Decision Tree Regressor")
print("MAE :", dt_mae)
print("MSE :", dt_mse)
print("RMSE:", dt_rmse)
print("R² Score:", dt_r2)
# Out:
# Decision Tree Regressor
# MAE : 1.9311649016641452
# MSE : 13.82375189107413
# RMSE: 3.7180306468712883
# R² Score: 0.022024689478959414

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)
rf_mse = mean_squared_error(y_test, rf_pred)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = r2_score(y_test, rf_pred)

print("Random Forest Regressor")
print("MAE :", rf_mae)
print("MSE :", rf_mse)
print("RMSE:", rf_rmse)
print("R² Score:", rf_r2)
# Out:
# Random Forest Regressor
# MAE : 1.2455068078668683
# MSE : 5.197569137670197
# RMSE: 2.279817786067605
# R² Score: 0.632292713915844

# %%
xgb_mae = mean_absolute_error(y_test, xgb_pred)
xgb_mse = mean_squared_error(y_test, xgb_pred)
xgb_rmse = np.sqrt(xgb_mse)
xgb_r2 = r2_score(y_test, xgb_pred)

print("XGBoost Regressor")
print("MAE:", xgb_mae)
print("MSE:", xgb_mse)
print("RMSE:", xgb_rmse)
print("R² Score:", xgb_r2)
# Out:
# XGBoost Regressor
# MAE: 1.0806140899658203
# MSE: 4.60820198059082
# RMSE: 2.146672303960439
# R² Score: 0.6739881038665771

# %%
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest', 'XGBoost'],
    'MAE': [lr_mae, dt_mae, rf_mae, xgb_mae],
    'MSE': [lr_mse, dt_mse, rf_mse, xgb_mse],
    'RMSE': [lr_rmse, dt_rmse, rf_rmse, xgb_rmse],
    'R² Score': [lr_r2, dt_r2, rf_r2, xgb_r2]
})

results
# Out:
#                Model       MAE        MSE      RMSE  R² Score
# 0  Linear Regression  1.127036   4.676523  2.162527  0.669155
# 1      Decision Tree  1.931165  13.823752  3.718031  0.022025
# 2      Random Forest  1.245507   5.197569  2.279818  0.632293
# 3            XGBoost  1.080614   4.608202  2.146672  0.673988

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, xgb_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color='red', linestyle='--')
plt.xlabel("Actual Exam Score")
plt.ylabel("Predicted Exam Score")
plt.title("Actual vs Predicted (XGBoost)")
plt.show()

# %%
residuals = y_test - xgb_pred
plt.figure(figsize=(8,6))
plt.scatter(xgb_pred, residuals, alpha=0.7)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted Exam Score")
plt.ylabel("Residuals")
plt.title("Residual Plot (XGBoost)")
plt.show()

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': xgb_model.feature_importances_
})

importance = importance.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(data=importance, x='Importance', y='Feature')
plt.title("Feature Importance (XGBoost)")
plt.show()

# %%
top = importance.head(10)
plt.figure(figsize=(8,5))
sns.barplot(data=top, x='Importance', y='Feature')
plt.title("Top 10 Important Features")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=results, x='Model', y='R² Score')
plt.title("Comparison of Regression Models")
plt.ylabel("R² Score")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=results, x='Model', y='RMSE')
plt.title("RMSE Comparison")
plt.ylabel("RMSE")
plt.show()

# %%
import joblib

joblib.dump(xgb_model, 'model.pkl')
joblib.dump(encoders, 'encoders.pkl')
joblib.dump(list(X.columns), 'columns.pkl')
print("Saved model.pkl, encoders.pkl, columns.pkl")
# Out:
# Saved model.pkl, encoders.pkl, columns.pkl

# %%
model = joblib.load('model.pkl')

new_student = pd.DataFrame({
    'Hours_Studied': [25],
    'Attendance': [90],
    'Parental_Involvement': [1],
    'Extracurricular_Activities': [1],
    'Sleep_Hours': [7],
    'Previous_Scores': [82],
    'Motivation_Level': [2],
    'Internet_Access': [1],
    'Tutoring_Sessions': [3],
    'Family_Income': [1],
    'Teacher_Quality': [2],
    'School_Type': [1],
    'Physical_Activity': [4],
    'Learning_Disabilities': [0],
    'Parental_Education_Level': [2],
    'Distance_from_Home': [1],
    'Gender': [1]
})

prediction = model.predict(new_student)

print("Predicted Exam Score:", prediction[0])
# Out:
# Predicted Exam Score: 70.83813
